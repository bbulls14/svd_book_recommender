# %%
import pandas as pd

# Load books data in chunks
books_iter = pd.read_csv('Books.csv', chunksize=100000)

# Combine chunks into a single DataFrame
books_df = pd.concat([chunk for chunk in books_iter])
books_df = books_df[~books_df.apply(lambda row: row.astype(str).str.contains('???').any(), axis=1)]

# # Load ratings data
# ratings_iter = pd.read_csv('Ratings.csv', chunksize=100000)
# ratings_df = pd.concat([chunk for chunk in ratings_iter])

# # Load users data
# users_iter = pd.read_csv('Users.csv', chunksize=100000)
# users_df = pd.concat([chunk for chunk in users_iter])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 8
#       6 # Combine chunks into a single DataFrame
#       7 books_df = pd.concat([chunk for chunk in books_iter])
# ----> 8 books_df = books_df[~books_df.apply(lambda row: row.astype(str).str.contains('???').any(), axis=1)]
#      10 # # Load ratings data
#      11 # ratings_iter = pd.read_csv('Ratings.csv', chunksize=100000)
#      12 # ratings_df = pd.concat([chunk for chunk in ratings_iter])
#    (...)
#      15 # users_iter = pd.read_csv('Users.csv', chunksize=100000)
#      16 # users_df = pd.concat([chunk for chunk in users_iter])
#
# File c:\Users\DELL\IdeaProjects\book\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
# ...

# %%
# Using pandas
# print(books_df.head())
# print(books_df.info())

# print(ratings_df.head())
# print(ratings_df.info())

# print(users_df.head())
# print(users_df.info())

# Print rows with missing values in any column
# Remove rows where any column contains '???'
print(books_df.head())
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 13
#       1 # Using pandas
#       2 # print(books_df.head())
#       3 # print(books_df.info())
#    (...)
#      11 # Print rows with missing values in any column
#      12 # Remove rows where any column contains '???'
# ---> 13 books_df = books_df[~books_df.apply(lambda row: row.astype(str).str.contains('???').any(), axis=1)]
#
# File c:\Users\DELL\IdeaProjects\book\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# ...
